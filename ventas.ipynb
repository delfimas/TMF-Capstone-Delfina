# %%
import pandas as pd
import numpy as np

# %%
df_calendario=pd.read_csv('/Users/delfina/Desktop/nuclioproyecto/TMF-Delfina/Data/daily_calendar_with_events.csv')
df_prices=pd.read_csv('/Users/delfina/Desktop/nuclioproyecto/TMF-Delfina/Data/item_prices.csv')
df_sales=pd.read_csv('/Users/delfina/Desktop/nuclioproyecto/TMF-Delfina/Data/item_sales.csv')

# %% [markdown]
# Analizo la tabla calendario.

# %%
df_calendario.head()
# Out:
#          date    weekday  weekday_int    d event
# 0  2011-01-29   Saturday            1  d_1   NaN
# 1  2011-01-30     Sunday            2  d_2   NaN
# 2  2011-01-31     Monday            3  d_3   NaN
# 3  2011-02-01    Tuesday            4  d_4   NaN
# 4  2011-02-02  Wednesday            5  d_5   NaN

# %%
df_calendario.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1913 entries, 0 to 1912
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1913 non-null   object
#  1   weekday      1913 non-null   object
#  2   weekday_int  1913 non-null   int64
#  3   d            1913 non-null   object
#  4   event        26 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 74.9+ KB

# %%
#Data type object to datetime

df_calendario['date']=pd.to_datetime(df_calendario['date'])

# %%
df_calendario.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1913 entries, 0 to 1912
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1913 non-null   datetime64[ns]
#  1   weekday      1913 non-null   object
#  2   weekday_int  1913 non-null   int64
#  3   d            1913 non-null   object
#  4   event        26 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 74.9+ KB

# %% [markdown]
# Create column 'YEARWEEK'

# %%
#calendario['yearweek']=calendario['date'].

# %%
df_calendario.isnull().sum()
# Out:
# date              0
# weekday           0
# weekday_int       0
# d                 0
# event          1887
# dtype: int64

# %%
df_calendario['event'].value_counts()
# Out:
# event
# SuperBowl         6
# Ramadan starts    5
# Thanksgiving      5
# NewYear           5
# Easter            5
# Name: count, dtype: int64

# %% [markdown]
# Analizo la tabla Ventas.

# %%
df_sales.head()
# Out:
#                        id              item    category    department  \
# 0  ACCESORIES_1_001_NYC_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 1  ACCESORIES_1_002_NYC_1  ACCESORIES_1_002  ACCESORIES  ACCESORIES_1
# 2  ACCESORIES_1_003_NYC_1  ACCESORIES_1_003  ACCESORIES  ACCESORIES_1
# 3  ACCESORIES_1_004_NYC_1  ACCESORIES_1_004  ACCESORIES  ACCESORIES_1
# 4  ACCESORIES_1_005_NYC_1  ACCESORIES_1_005  ACCESORIES  ACCESORIES_1
#
#                store store_code    region  d_1  d_2  d_3  ...  d_1904  d_1905  \
# 0  Greenwich_Village      NYC_1  New York    0    0    0  ...       1       3
# 1  Greenwich_Village      NYC_1  New York    0    0    0  ...       0       0
# 2  Greenwich_Village      NYC_1  New York    0    0    0  ...       2       1
# 3  Greenwich_Village      NYC_1  New York    0    0    0  ...       1       0
# 4  Greenwich_Village      NYC_1  New York    0    0    0  ...       2       1
#
#    d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# ...

# %%
len(df_sales.columns)
# Out:
# 1920

# %%
df_sales.index
# Out:
# RangeIndex(start=0, stop=30490, step=1)

# %%
df_sales.describe()
# Out:
#                 d_1           d_2           d_3           d_4           d_5  \
# count  30490.000000  30490.000000  30490.000000  30490.000000  30490.000000
# mean       1.070220      1.041292      0.780026      0.833454      0.627944
# std        5.126689      5.365468      3.667454      4.415141      3.379344
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      360.000000    436.000000    207.000000    323.000000    296.000000
#
#                 d_6           d_7           d_8           d_9          d_10  \
# count  30490.000000  30490.000000  30490.000000  30490.000000  30490.000000
# mean       0.958052      0.918662      1.244080      1.073663      0.838701
# ...

# %%
#
